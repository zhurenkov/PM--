# %% [markdown]
# # Пример

# %%
print("Hello World!")
a=3
b=4
c=pow(a**2+b**2,.5)
print(c)
# Out:
# Hello World!
# 5.0

# %% [markdown]
# $$c = \sqrt{a^2 + b^2}$$

# %%
import pandas as pd
allSales = pd.read_csv('Sales.txt', sep='\t', encoding='cp1251', header=0,)
allSales.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112 entries, 0 to 111
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Чек            112 non-null    object
#  1   Код товара     112 non-null    int64
#  2   Цена           112 non-null    object
#  3   Карта клиента  112 non-null    int64
#  4   Дата           112 non-null    object
#  5   Точка продажи  112 non-null    int64
#  6   Способ оплаты  112 non-null    object
#  7   Тип карты      112 non-null    object
#  8   Количество     112 non-null    int64
#  9   Сумма          112 non-null    object
# dtypes: int64(4), object(6)
# memory usage: 54.4 KB

# %%
allSales
# Out:
#                    Чек  Код товара   Цена  Карта клиента                 Дата  \
# 0          CH567206413      353032   66,6        3322382  20.12.2013 14:24:00
# 1          CH576427054      353267  442,2        3113313  23.12.2013 12:07:00
# 2          CH655930931      353420    760          21011  13.01.2014 12:25:00
# 3          CH664659904      350832    424       54422002  15.01.2014 15:55:00
# 4          CH692870025      353564    124         110864  22.01.2014 17:41:00
# ..                 ...         ...    ...            ...                  ...
# 107  CH939416641010920      353090  283,8       19517636  21.02.2013 11:10:00
# 108   CH93544697703271      352309   2490         215732   22.09.2012 9:15:00
# 109  CH939486103011115      352500   92,8        6688702  03.12.2012 16:49:00
# 110    CH1020104530088      350122  309,4          14813  23.10.2012 14:29:00
# 111   CH10720598330392      353090  283,8       15916095  23.09.2012 13:05:00
#
# ...

# %%
allSales.head(20)
# Out:
#             Чек  Код товара    Цена  Карта клиента                 Дата  \
# 0   CH567206413      353032    66,6        3322382  20.12.2013 14:24:00
# 1   CH576427054      353267   442,2        3113313  23.12.2013 12:07:00
# 2   CH655930931      353420     760          21011  13.01.2014 12:25:00
# 3   CH664659904      350832     424       54422002  15.01.2014 15:55:00
# 4   CH692870025      353564     124         110864  22.01.2014 17:41:00
# 5   CH700581231      350009  1028,4       42820841  24.01.2014 12:16:00
# 6   CH841052065      353536    81,8        1904709  27.02.2014 15:58:00
# 7   CH869067978      352112    14,6       92222525  06.03.2014 10:43:00
# 8   CH953321426      353304    69,2       27322055  25.03.2014 16:17:00
# 9   CH935967468      353687    38,6        1642077  11.04.2010 20:09:00
# 10  CH940049863      353219   239,4        3715494  05.04.2013 14:34:00
# 11  CH936154497      353727   686,4        2146786  04.05.2010 13:30:00
# ...

# %%
allSales.set_index("Чек", inplace=True)
allSales.head()
# Out:
#              Код товара   Цена  Карта клиента                 Дата  \
# Чек
# CH567206413      353032   66,6        3322382  20.12.2013 14:24:00
# CH576427054      353267  442,2        3113313  23.12.2013 12:07:00
# CH655930931      353420    760          21011  13.01.2014 12:25:00
# CH664659904      350832    424       54422002  15.01.2014 15:55:00
# CH692870025      353564    124         110864  22.01.2014 17:41:00
#
#              Точка продажи Способ оплаты Тип карты  Количество   Сумма
# Чек
# CH567206413           1060      наличные   красная           6  379,62
# CH576427054           1060      наличные   красная           2  840,18
# CH655930931           1062      наличные   красная           2    1444
# CH664659904           1060      наличные   красная           2   805,6
# CH692870025           1060      наличные   красная           2   235,6

# %%
allSales.describe()
# Out:
#           Код товара  Карта клиента  Точка продажи  Количество
# count     112.000000   1.120000e+02     112.000000  112.000000
# mean   351747.857143   3.365250e+07    1063.750000    3.642857
# std      1209.340494   3.405770e+07       7.194217    4.421196
# min    350009.000000   1.481300e+04    1060.000000    2.000000
# 25%    350519.250000   5.197932e+06    1060.000000    2.000000
# 50%    352022.500000   1.641338e+07    1060.000000    2.000000
# 75%    352778.000000   6.466512e+07    1062.000000    2.000000
# max    353727.000000   9.881790e+07    1080.000000   20.000000

# %%
import numpy as np
allSales.groupby("Карта клиента").sum()
allSales.head()
# Out:
#              Код товара   Цена  Карта клиента                 Дата  \
# Чек
# CH567206413      353032   66,6        3322382  20.12.2013 14:24:00
# CH576427054      353267  442,2        3113313  23.12.2013 12:07:00
# CH655930931      353420    760          21011  13.01.2014 12:25:00
# CH664659904      350832    424       54422002  15.01.2014 15:55:00
# CH692870025      353564    124         110864  22.01.2014 17:41:00
#
#              Точка продажи Способ оплаты Тип карты  Количество   Сумма
# Чек
# CH567206413           1060      наличные   красная           6  379,62
# CH576427054           1060      наличные   красная           2  840,18
# CH655930931           1062      наличные   красная           2    1444
# CH664659904           1060      наличные   красная           2   805,6
# CH692870025           1060      наличные   красная           2   235,6

# %%
allSales.describe()
# Out:
#           Код товара  Карта клиента  Точка продажи  Количество
# count     112.000000   1.120000e+02     112.000000  112.000000
# mean   351747.857143   3.365250e+07    1063.750000    3.642857
# std      1209.340494   3.405770e+07       7.194217    4.421196
# min    350009.000000   1.481300e+04    1060.000000    2.000000
# 25%    350519.250000   5.197932e+06    1060.000000    2.000000
# 50%    352022.500000   1.641338e+07    1060.000000    2.000000
# 75%    352778.000000   6.466512e+07    1062.000000    2.000000
# max    353727.000000   9.881790e+07    1080.000000   20.000000
